# %%
import time
import numpy as np
import pandas as pd


CITY_DATA = { 'chicago': 'chicago.csv',
             'new york': 'new_york_city.csv', 
             'washington': 'washington.csv'}


def get_filters():
    
    """
    Asks user to specify a city, month, and day to analyze.
    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    
    print('Hello! Let\'s explore some US bikeshare data!')
    
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    
    city = input('please choose city name to analyse: [chicago , new york  , washington] ').lower()
    while city not in CITY_DATA.keys():
        print('Not founded , please try again..')
        city = input('please choose city name to analyse  {chicago , new york  , washington} ').lower()
        return city
    

    # TO DO: get user input for month (all, january, february, ... , june)
    
    months = ['january', 'february', 'march', 'april', 'may', 'june' , 'all']
    month = input("please choose month name to analyse: ['january', 'february', 'march', 'april', 'may', 'june' , 'all']").lower()
    
    while month not in months:
        print(' Not founded , please try again..')
        month = input("please choose month name to analyse: ['january', 'february', 'march', 'april', 'may', 'june' , 'all']").lower()
        print(month)

        
    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    
    days = ['sunday' ,'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday' , 'all']
    day = input("please choose day name to analyse: ['sunday' ,'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday' , 'all']").lower()
                
    while day not in days:
        print('Not founded , please try again..')
        day = input("please choose day name to analyse: ['sunday' ,'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday' , 'all']").lower()
        print(day)
    

                    
    print('-'*40)
    return city, month, day


def load_data(city, month, day):
                    
    """
    Loads data for the specified city and filters by month and day if applicable.
    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    # loading the data 
    data = pd.read_csv(CITY_DATA[city])
    
    #convert staet time column to datatime  
    data['Start Time'] = pd.to_datetime(data['Start Time'])

    #creat new columns with months and days  
    
    data['month'] = data['Start Time'].dt.month
    data['day_of_week'] = data['Start Time'].dt.day_name()


    # filtering by month name 
    
    if month != 'all':
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1
        data = data[data['month'] == month]

    # filter by day name 
    
    if day != 'all':
        data = data[data['day_of_week'] == day.title()]

    return data


def time_stats(data):
    """Displays statistics on the most frequent times of travel."""

    
    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    
    months = ['january', 'february', 'march', 'april', 'may', 'june']
    month = data['month'].mode()[0]
    print(f'The most common month is: {months[month-1]}')

    # TO DO: display the most common day of week
    
    day = data['day_of_week'].mode()[0]
    print(f'The most common day of week is: {day}')

     # TO DO: display the most common start hour
    
    data['hour'] = data['Start Time'].dt.hour
    popular_hour = data['hour'].mode()[0]
    print(f'The most common start hour is: {popular_hour}')

    
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def station_stats(data):
                    
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
                    
    popular_start_station = data['Start Station'].mode()[0]
    print(f'The most popular start station is: {popular_start_station}')

     # TO DO: display most commonly used end station
        
    popular_end_station = data['End Station'].mode()[0]
    print(f'The most popular end station is: {popular_end_station}')

    # TO DO: display most frequent combination of start station and end station trip
    
    popular_trip = data['Start Station'] + ':' + data['End Station']
    print(f'The most popular trip is: from {popular_trip.mode()[0]}')

    print("\n This took %s seconds." % (time.time() - start_time))
    print('-'*40)


def trip_duration_stats(data):         
                    
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    from datetime import timedelta as td                
    start_time = time.time()

    # TO DO: display total travel time
    print("Total travel time: ", data['Trip Duration'].sum())
    
    

    # TO DO: display mean travel time
    print("Average travel time: ", data['Trip Duration'].mean())
    


    print("\n This took %s seconds." % (time.time() - start_time))
    print('-'*40)


def user_stats(data):
                    
    """Displays statistics on bikeshare users."""

    print('\n Calculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    
    print(data['User Type'].value_counts())
    print('  \n\n  ')

    # TO DO: Display counts of gender
    
   # if 'Gender' in(data.columns):
        #print(data['Gender'].value_counts())
   
    if city !=  ["washington"]:
         print(data['Gender'].value_counts())

     # TO DO: Display earliest, most recent, and most common year of birth
        
         print("earliest year is: ",int(data['Birth Year'].min()))
         print("most recent year is: ",int(data['Birth Year'].max()))
         print("most common year is: ",int(data['Birth Year'].mode()))

    else:
        print("Not available data")
   
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def display_five_rows(data):
      
    R = 0
    Data = input("did  you want to see  raw data? Type 'yes' or 'no'.").lower()
                    
    while True:
        if Data == "no":
            break
            
     #display next five rows           
        print(data[R:R+5]) 
        Data = input("did  you want to see  raw data? Type 'yes' or 'no'.").lower()
        R += 5


def main():
            
    while True:
        city, month, day = get_filters()
        data = load_data(city, month, day)
        
        
        time_stats(data)
        station_stats(data)
        trip_duration_stats(data)
        user_stats(data)
        display_five_rows(data)
        
        
        restart = input('\n Would you like to restart? Enter yes or no. \n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
	main()
# Out:
# Hello! Let's explore some US bikeshare data!
# please choose city name to analyse: [chicago , new york  , washington] chicago
# please choose month name to analyse: ['january', 'february', 'march', 'april', 'may', 'june' , 'all']march
# please choose day name to analyse: ['sunday' ,'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday' , 'all']sunday
# ----------------------------------------
#
# Calculating The Most Frequent Times of Travel...
#
# The most common month is: march
# The most common day of week is: Sunday
# The most common start hour is: 15
#
# This took 0.001994609832763672 seconds.
# ----------------------------------------
#
# Calculating The Most Popular Stations and Trip...
#
# The most popular start station is: Streeter Dr & Grand Ave
# The most popular end station is: Streeter Dr & Grand Ave
# The most popular trip is: from Calumet Ave & 33rd St:State St & 33rd St
#
#  This took 0.2314453125 seconds.
# ----------------------------------------
#
# ...

# %%
def display_row_data(df):
    print('\nRaw data is avalible to check...\n')
    index=0
    user_input=input('would you like to view 5 rows of row data?,please type yes or no ').lower()
    if user_input not in ['yes','no']:
        print('that is invalid input,please type yes or no')
        user_input=input('would you like to view 5 rows of row data?,please type yes or no ').lower()
    elif user_input!= 'yes':
        print ('thank you')
    else:
        while index+5< df.shape[0]:
            print (df.iloc[index:index+5])
            index +=5
           
            if user_input!='yes':
                print("thank you")
                break
